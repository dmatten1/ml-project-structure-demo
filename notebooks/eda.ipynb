# %% [markdown]
# # Exploring the data prior to modeling
# Inspect the dataset to guide model development

# %%
# Move the execution of the folder up one directory to place the src in the path
import os
import pandas as pd
os.chdir('..')

# %%
import src.common.tools as tools
import matplotlib.pyplot as plt
import src.data.dataio as dataio

config = tools.load_config()
filepath = config["dataprocesseddirectory"] + "train.csv"
[X, y] = dataio.load(filepath)
print(X)
# Out:
# [[ 0.47540328  0.79308916  0.97301085  1.480196  ]
#  [-0.7000444   1.44793342 -1.33890804 -1.35148331]
#  [-0.81758917 -0.73488078  0.01441033  0.19306904]
#  [-0.22986532 -1.17144362  0.63468126  0.96534522]
#  [ 1.41576143 -0.08003652  1.14217565  1.09405792]
#  [ 1.5333062   0.35652632  1.19856391  0.70791983]
#  [ 2.12103004 -0.9531622   1.70605831  1.35148331]
#  [ 0.82803759 -0.29831794  0.40912819  0.06435635]
#  [-0.46495486  1.01137058 -1.45168457 -1.35148331]
#  [-1.28776824  0.79308916 -1.11335498 -1.35148331]
#  [ 0.59294805  0.1382449   0.91662259  0.70791983]
#  [-1.17022347 -1.17144362  0.35273993  0.57920713]
#  [-0.93513393  1.01137058 -1.39529631 -1.22277061]
#  [ 2.00348527 -0.08003652  1.53689351  1.09405792]
#  [-0.11232056 -0.73488078  0.01441033 -0.06435635]
#  [-0.34741009 -0.51659936  0.57829299  0.96534522]
#  [ 0.47540328 -1.17144362  0.63468126  0.83663252]
#  [ 0.71049282  0.35652632  0.69106952  0.96534522]
# ...

# %%
curtest_master = pd.read_csv("./data/processed/curtest_master.csv")
curtest_master
# Out:
# /var/folders/dk/2mw0y5w91dggrsnrpxb04jv80000gn/T/ipykernel_92662/1040074768.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   curtest_master = pd.read_csv("./data/processed/curtest_master.csv")
#              testdt  lea  schlcode  year test_id  score  ach_level grade  \
# 0        2022-05-01  80C         0  2022    MA03  550.0          3    03
# 1        2022-05-01  80C         0  2022    RD03  547.0          4    03
# 2        2022-05-01  320       316  2022    MA08  547.0          3    08
# 3        2022-05-01  320       316  2022    RD08  557.0          3    08
# 4        2022-05-01  320       316  2022    SC08  259.0          4    08
# ...             ...  ...       ...   ...     ...    ...        ...   ...
# 6651491  2018-06-01  010       380  2018    MA03  449.0          3   3.0
# 6651492  2018-06-01  010       380  2018    RD03  430.0          1   3.0
# ...

# %%
gpa_master = pd.read_csv("./data/processed/gpa_master.csv")
gpa_master
# Out:
#         lea  schlcode  gpa_unweighted  gpa_weighted  rank_unweighted  \
# 0       910       370          3.2245        3.2245             35.0
# 1       920       552          4.0000        4.0000              1.0
# 2       920       436          4.0000        4.0000              1.0
# 3       920       436          3.4343        3.4343            114.0
# 4       920       441          3.6667        3.6667            251.0
# ...     ...       ...             ...           ...              ...
# 493867  410       394          1.7778        2.1481            360.0
# 493868  600       592          3.4333        4.1333             24.0
# 493869  410       595          2.8077        3.3846            152.0
# 493870  410       355          1.3704        1.4815            272.0
# 493871  410       529          2.3448        2.3793            252.0
#
#         rank_weighted  rank_number_unweight  rank_number_weighted  SCHOOL  \
# ...
